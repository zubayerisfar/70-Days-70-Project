# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">⚡Forecasting Hourly Electricity Consumption and Production Using RNN and LSTM🔌💡</p>

# %% [markdown]
# ![_f3f8537a-4fe2-44b3-a643-9548574ff6e0 (1).jpg](attachment:3bcd8f56-66e4-42d0-8cc1-0556f6b33ce9.jpg)

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">About Dataset</p>

# %% [markdown]
# * This is Hourly timeseries Electricity Consumption and production Dataset.
# * It includes the hourly consumption and production, and the production is split in one of the categories: Nuclear, Wind, Hydroelectric, Oil and Gas, Coal, Solar, Biomass.
# * It's a  big data set of more than 5 years!
# * When the production is greater than the consumption it means we are exporting electricity, when the value is smaller it means we are importing electricity.
# * All values of this dataset are in MWs.
# * This Dataset can be used to analyze various trends and patterns such as Seasonal Variations, Renewable Energy Contributions, Fossil Fuel Dependence.
# * The dataset can be used to drive innovation in energy technologies, such as the development of more efficient storage systems.
# * as this is more than 5 years dataset so this data can be used to conduct detailed statistical analysis, forecasting future trends, and developing models for optimizing electricity production and its consumption.

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">About Dataset Columns</p>

# %% [markdown]
# | **Column**            | **Description**                                                                 |
# |-----------------------|---------------------------------------------------------------------------------|
# | **Timestamp**         | The date and hour of the recording (e.g., YYYY-MM-DD HH:00).                    |
# | **Consumption (MW)**  | The total electricity consumption in megawatts (MW) during that hour.           |
# | **Total Production (MW)** | The total electricity production in megawatts (MW) during that hour.       |
# | **Nuclear (MW)**      | Electricity produced from nuclear power plants.                                 |
# | **Wind (MW)**         | Electricity produced from wind turbines.                                        |
# | **Hydroelectric (MW)** | Electricity produced from hydroelectric power plants.                          |
# | **Oil and Gas (MW)**  | Electricity produced from oil and gas power plants.                             |
# | **Coal (MW)**         | Electricity produced from coal power plants.                                    |
# | **Solar (MW)**        | Electricity produced from solar panels.                                         |
# | **Biomass (MW)**      | Electricity produced from biomass energy sources.                               |

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Aims and Objectives</p>

# %% [markdown]
# * This is Hourly timeseries Electricity Consumption and production Dataset.
# * The Main Aim to take this Dataset is that to explore about the hourly elecricity production and consumption and forecast with RNN and LSTM.
# * For this I Firstly Load and Display the Dataset and then i create the plots in order to explore the dataset and took the insights about ELectricity production and Consumption.
# * Then I apply the RNN na LSTM to forecast Electricity consumption

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Dataset Link</p>

# %% [markdown]
# **Dataset link:** https://www.kaggle.com/datasets/stefancomanita/hourly-electricity-consumption-and-production/data

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">About Author</p>

# %% [markdown]
# *

# %% [markdown]
# * Hii Kagglers! I'm Maria Nadeem and I am a passionate Data Scientist.
# * I'm constantly exploring and applying various Data Science techniques pationationatly.
# * I'm thrilled  to share my notebooks with kaggle community.
# * I always excited to contribute to the Kaggle community by sharing my detailed analyses and actionable insights through my projects.
# * In this Notebook, I Firstly explore the each column of the dataset by creating visualization plots and by taking insights about the Dtaset.
# * Then in order to forecast the data i apply LSTM and RNN
# * Let's grow, collaborate, learn, innovate together!

# %% [markdown]
# | Name               | Email                                               | LinkedIn                                                  | GitHub                                           | Kaggle                                        |
# |--------------------|-----------------------------------------------------|-----------------------------------------------------------|--------------------------------------------------|-----------------------------------------------|
# | **Maria Nadeem**  | marianadeem755@gmail.com | <a href="https://www.linkedin.com/in/maria-nadeem-4994122aa/" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/LinkedIn-%2300A4CC.svg?style=for-the-badge&logo=LinkedIn&logoColor=white" alt="LinkedIn Badge"></a> | <a href="https://github.com/marianadeem755" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/GitHub-%23FF6F61.svg?style=for-the-badge&logo=GitHub&logoColor=white" alt="GitHub Badge"></a> | <a href="https://www.kaggle.com/marianadeem755" style="text-decoration: none; font-size: 16px;"><img src="https://img.shields.io/badge/Kaggle-%238a2be2.svg?style=for-the-badge&logo=Kaggle&logoColor=white" alt="Kaggle Badge"></a> |

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Import Libraries</p>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,GRU, Dense, Bidirectional
from tensorflow.keras.layers import SimpleRNN, Dense
from tensorflow.keras.layers import TimeDistributed, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Lets Load and Display the Dataset</p>

# %%
# Load the data
df = pd.read_csv('data/elec_cnsmp_data.csv')
df.head()
# Out:
#               DateTime  Consumption  Production  Nuclear  Wind  Hydroelectric  \
# 0  2019-01-01 00:00:00         6352        6527     1395    79           1383
# 1  2019-01-01 01:00:00         6116        5701     1393    96           1112
# 2  2019-01-01 02:00:00         5873        5676     1393   142           1030
# 3  2019-01-01 03:00:00         5682        5603     1397   191            972
# 4  2019-01-01 04:00:00         5557        5454     1393   159            960
#
#    Oil and Gas  Coal  Solar  Biomass
# 0         1896  1744      0       30
# 1         1429  1641      0       30
# 2         1465  1616      0       30
# 3         1455  1558      0       30
# 4         1454  1458      0       30

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Lets Explore the Electricity trends over time</p>

# %% [markdown]
# ## **About Code:**
# * Firstly in this code the list is being defined of  the energy sources which we have to plot.
# * Then Figure and an array of subplots is created using `plt.subplots()`.
# * Then the number of rows of subplots, which is equal to the number of energy sources is being specified by `nrows=len(energy_sources)`
# * Then nccolumns is being specified and here only 1 column of subplots is taken using `ncols=1`.
# * Then the figsize is defined.
# * Then `sharex=True` is used to ensures all subplots share the same x-axis.
# * Then shows the subplots.

# %%
import matplotlib.pyplot as plt

# Define the energy sources of interest
energy_sources = ['Oil and Gas', 'Coal', 'Solar', 'Biomass']

# Create subplots for the selected energy sources
fig, axes = plt.subplots(nrows=len(energy_sources), ncols=1, figsize=(14, 7), sharex=True)

# Plot each energy source in its own subplot
for i, source in enumerate(energy_sources):
    axes[i].plot(df.index, df[source], label=source)
    axes[i].set_ylabel('energy sources')
    axes[i].set_title(f'{source} energy sources')
    axes[i].grid(True)

# Set common x-axis label and adjust layout
plt.xlabel('Date Time')
plt.tight_layout()
plt.show()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">lets take a Glimpse at the Distribution of Electricity Generation by Source</p>

# %% [markdown]
# * This code is being used to create the Histogram that visually comparing the distributions of electricity generation from different sources (nuclear, wind, hydroelectric) using histograms.
# * The histograms help in understanding how the electricity generation varies across these different sources such as nuclear, wind, hydroelectric.
# * By this code Three Histograms are created of Numclear, Wind and Hydroelectric Columns.
# * Then the parameters are defined to create the plot.
# * Then set the x and y label and Displays a legend that identifies each histogram by its label such as 'Nuclear', 'Wind', 'Hydroelectric'.
# * Then Add the grid lines to the plot, which can ususally help in better understanding the distribution.
# * Finally Displays the plot.

# %%
plt.figure(figsize=(14, 7))

plt.hist(df['Nuclear'], bins=50, alpha=0.5, label='Nuclear', color='blue')
plt.hist(df['Wind'], bins=50, alpha=0.5, label='Wind', color='green')
plt.hist(df['Hydroelectric'], bins=50, alpha=0.5, label='Hydroelectric', color='orange')

plt.xlabel('Electricity (MW)')
plt.ylabel('Frequency')
plt.title('Distribution of Electricity Generation by Source')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Observation:
# * The Histogram shows that the Frequency of  production of Nuclear, wind and Hydroelectric.
# * By this plot it is shown that Nuclear production is Higher than wind and Hydroelectric.

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">lets have a sneakpeak at lineplot of Hourly Electricity Consumption and Production</p>

# %% [markdown]
# ## **About Code:**
# * This code is being used for visually comparing the trends of hourly electricity consumption and production over a period of time according to this dataset.
# * By plotting the lineplot on the same graph, one can easily observe patterns such as peaks, dips, and correlations between consumption and production trends of the Electricity.
# * Two line plots are created on the same figure using this code of the consumption and production of electricity.
# * Then the x, y labels and legends are being shown.
# * Then Add the grid lines to the plot, which can help in better understanding the values and trends over time of the Electricity production and Consumption.
# * Finally, displays the plot with all the specified features using plt.show().

# %%
plt.figure(figsize=(14, 7))
plt.plot(df.index, df['Consumption'], label='Consumption', color='blue')
plt.plot(df.index, df['Production'], label='Production', color='green')

plt.xlabel('Date Time')
plt.ylabel('Electricity (MW)')
plt.title('Hourly Electricity Consumption and Production')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">lets Display Hourly Electricity Production by Source with a Stacked Area Plot</p>

# %% [markdown]
# ## **About Code:**
# * This code is being used for visualizing the contribution of different energy sources to hourly electricity production over time the electricity production in megawatts (MW) from each respective source.
# * The stacked area plot helps in understanding how each energy source contributes to the total electricity production throughout the time period.
# * Stacked Area Plot which is created typically represents the datetime index and indicat the time intervals.
# * Firstly generates a list where each inner list contains the values of electricity production.
# * Then display the x, y label and the legends.
# * Then Add the grid lines to the plot, which can help in better understanding the values and trends over time of sources of electricity.
# * Finally, displays the stacked area plot.

# %%
plt.figure(figsize=(14, 7))

plt.stackplot(df.index, [df[source] for source in energy_sources], labels=energy_sources)

plt.xlabel('Date Time')
plt.ylabel('Electricity Production (MW)')
plt.title('Hourly Electricity Production by Source (Stacked Area Plot)')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">lets have a sneakpeak at the Lagplot</p>

# %% [markdown]
# ## **Lagplot:**
# * A lag plot is a special type of scatter plot in which the X-axis represents the dataset with some time units behind or ahead as compared to the Y-axis.
# * The difference between these time units is called lag or lagged and it is represented by k.
# * Lagging a time series means to shift its values forward one or more time steps, or equivalently, to shift the times in its index backward one or more steps.
# * These lag plots which is displayed here are useful for visually inspecting whether there is any autocorrelation present in the electricity consumption and production.
# * Hence, the Autocorrelation can be used to indicate patterns or dependencies in the data, where the value at one time point is related to the value at a previous time pointin the data.

# %% [markdown]
# ## **About Code:**
# * lag_plot(df['Consumption'])and lag_plot(df['Production']) is used to Generates the lag plot of consumption and production column.
# * Then labels and titles are defined.
# * then create the grid and display the plot

# %%
# Convert the 'DateTime' column to datetime
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
plt.figure(figsize=(10, 6))
lag_plot(df['Consumption'])
plt.title('Lag Plot of Electricity Consumption')
plt.xlabel('Consumption(t)')
plt.ylabel('Consumption(t + 1)')
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
lag_plot(df['Production'])
plt.title('Lag Plot of Electricity Production')
plt.xlabel('Production(t)')
plt.ylabel('Production(t + 1)')
plt.grid(True)
plt.show()

# %% [markdown]
# - সম্পর্ক (Relationship): এটি একটি নির্দিষ্ট সময়ের ($t$) এবং ঠিক তার পরবর্তী সময়ের ($t+1$) এনার্জি ব্যবহারের মধ্যকার সম্পর্ক দেখায়।
#
# - সরলরৈখিক প্যাটার্ন (Linear Pattern): বিন্দুগুলো মিলে একটি ঘন, কোণাকুণি বা ডায়াগোনাল রেখা তৈরি করেছে। এর মানে হলো, বর্তমান সময়ে এনার্জির ব্যবহার যেমন থাকে, ঠিক পরের ধাপেও ব্যবহার প্রায় একই রকম বা কাছাকাছি থাকে (যাকে Strong Positive Autocorrelation বলা হয়)।
# - ব্যতিক্রম বা আউটলায়ার (Anomalies): মূল ঘন রেখাটির বাইরে ছড়িয়ে থাকা বিক্ষিপ্ত বিন্দুগুলো হঠাৎ করে বিদ্যুৎ ব্যবহার অস্বাভাবিকভাবে বেড়ে যাওয়া বা কমে যাওয়া নির্দেশ করে। এগুলো হলো Outliers।
#
# সংক্ষেপে, এই প্লট প্রমাণ করে যে আপনার ডেটাসেটের অতীত এবং বর্তমানের মধ্যে খুব শক্তিশালী সম্পর্ক রয়েছে, যা ভবিষ্যৎ প্রেডিক্ট করার জন্য চমৎকার।

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">lets have a Glimpse at Hydroelectric, Oil and Gas</p>

# %% [markdown]
# * `Autocorrelation` refers to the degree of correlation of the same variables between two successive time intervals.
# * `An autocorrelation plot also known as ACF plot` used for identifying the presence of autocorrelation.
# * It measures how the lagged version of the value of a variable is related to the original version of it in a time series.
# * autocorrelation_plot`(df['Hydroelectric']),autocorrelation_plot(df['Oil and Gas'])` is used to display the autocorrelation plot.
# * Then labels and titles are defined.
# * Then create the grid and display the plot

# %%
plt.figure(figsize=(10, 6))
autocorrelation_plot(df['Hydroelectric'])
plt.title('Autocorrelation Plot of Hydroelectric, Oil and Gas')
plt.grid(True)
plt.show()
plt.figure(figsize=(10, 6))
autocorrelation_plot(df['Oil and Gas'])
plt.title('Autocorrelation Plot of Hydroelectric, Oil and Gas')
plt.grid(True)
plt.show()

# %% [markdown]
# - **ঢেউ খেলানো প্যাটার্ন (Wavy/Oscillating Pattern)**: গ্রাফটি বারবার উপরে উঠছে এবং নিচে নামছে। এর মানে হলো ডেটাটি একটি নির্দিষ্ট সময় পরপর নিজের আগের অবস্থায় ফিরে যায় বা একই রকম আচরণ করে। হাইড্রোইলেকট্রিক, অয়েল এবং গ্যাসের ব্যবহারের ক্ষেত্রে এটি সাধারণত বাৎসরিক ঋতু পরিবর্তনের (যেমন শীত বা গ্রীষ্মে এনার্জির চাহিদার পার্থক্য) কারণে হয়ে থাকে।
#
# - **পিক বা চূড়া (Peaks at Specific Lags)**: X-অ্যাক্সিসে (Lag) খেয়াল করলে দেখবেন, বেশ বড় ব্যবধানে (যেমন প্রায় ৯,০০০, ১৮,০০০, ২৭,০০০ ল্যাগে) একেকটি পজিটিভ চূড়া তৈরি হয়েছে। যদি আপনার এই ডেটাসেটটি প্রতি ঘণ্টার (hourly) হিসাব হয়, তবে এক বছরে ৮৭৬০ ঘণ্টা থাকে। অর্থাৎ, এই চূড়াগুলো প্রমাণ করে যে প্রতি বছরের ঠিক একই সময়ে (যেমন গত বছরের আজকের দিনে) এনার্জি ব্যবহারের মধ্যে দারুণ মিল রয়েছে।
#
# - **সম্পর্ক হ্রাস (Decaying Correlation)**: গ্রাফের ডানদিকে যত যাওয়া যাচ্ছে (অর্থাৎ ল্যাগ যত বাড়ছে), ঢেউয়ের উচ্চতা বা চূড়াগুলো তত ছোট হয়ে আসছে এবং এটি শূন্যের (০.০০) কাছাকাছি চলে যাচ্ছে। এর মানে হলো— গতকালের বা গত বছরের ডেটার সাথে আজকের ডেটার মিল যতটা বেশি, ৫ বা ১০ বছর আগের ডেটার সাথে আজকের মিল ততটা শক্তিশালী নয়। দূরের অতীতের প্রভাব সময়ের সাথে সাথে ধীরে ধীরে কমতে থাকে।

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">lets have a look at Proportion of Total Electricity Production</p>

# %% [markdown]
# * The code is used to visualize the proportion of total electricity production of different energy sources using a pie chart.
# * firstly calculates the total production for each energy source of electricity.
# * `df[energy_sources].sum():` is used to calculate the total production for each energy source specified in the energy_sources of this dataset.
# * It then plots this data as a pie chart where each segment represents the proportion or percentage of total production for a specific energy source of electricity.
# * Then the colors are customized and the plot are shown to includes a title.

# %%
total_production_by_source = df[energy_sources].sum()

plt.figure(figsize=(10, 10))
total_production_by_source.plot(kind='pie', autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6','#c4e17f'])

plt.ylabel('')
plt.title('Proportion of Total Electricity Production by Source')
plt.show()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Correlation Matrix of Electricity Production and Consumption Dataset</p>

# %%
plt.figure(figsize=(12, 6))
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='viridis', linewidths=0.5)

plt.title('Correlation Matrix of Electricity Data')
plt.show()

# %% [markdown]
# ## **Observations:**
# * The correlaation matrix shows that there is high positive correlation among Production of electricity and Hydroelectric.
# * Similarly there is high correlation among consumption and coal, oil and gas
# * There is negative correlation or very less correlation among the DateTime, and coal, Nuclear and Hydroelectric, Solar and Biomass, DateTime and Biomass

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">RNN-Based Time Series Forecasting of Electricity Consumption</p>

# %%
# Normalize the data
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df[['Consumption', 'Production', 'Nuclear', 'Wind', 'Hydroelectric', 'Oil and Gas', 'Coal', 'Solar', 'Biomass']])

# Convert to a DataFrame
scaled_df = pd.DataFrame(scaled_df, columns=['Consumption', 'Production', 'Nuclear', 'Wind', 'Hydroelectric', 'Oil and Gas', 'Coal', 'Solar', 'Biomass'])

# Create sequences
def create_sequences(df, seq_length):
    sequences = []
    labels = []
    for i in range(len(df) - seq_length):
        seq = df.iloc[i:i+seq_length].values
        label = df['Consumption'].iloc[i+seq_length]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

SEQ_LENGTH = 24  # for 24 hours sequence
sequences, labels = create_sequences(scaled_df, SEQ_LENGTH)

# %%
sequences.shape, labels.shape
# Out:
# ((54146, 24, 9), (54146,))

# %%
sequences[:1], labels[:1]
# Out:
# (array([[[0.51247572, 0.50362051, 0.93072626, 0.03701093, 0.28363466,
#           0.87410072, 0.64880425, 0.        , 0.18055556],
#          [0.477215  , 0.38155756, 0.92849162, 0.04300317, 0.2200047 ,
#           0.63412127, 0.60318866, 0.        , 0.18055556],
#          [0.44090841, 0.37786316, 0.92849162, 0.05921748, 0.20075135,
#           0.65262076, 0.59211692, 0.        , 0.18055556],
#          [0.41237113, 0.36707551, 0.93296089, 0.07648925, 0.18713313,
#           0.64748201, 0.56643047, 0.        , 0.18055556],
#          [0.39369491, 0.34505689, 0.92849162, 0.06520973, 0.18431557,
#           0.64696814, 0.52214349, 0.        , 0.18055556],
#          [0.38891379, 0.33486035, 0.93072626, 0.04124075, 0.18384597,
#           0.64748201, 0.52125775, 0.        , 0.18055556],
#          [0.38712087, 0.32954042, 0.9273743 , 0.04370814, 0.17915004,
#           0.64542652, 0.51417183, 0.        , 0.19444444],
# ...

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.2, shuffle=False)

# Simple RNN Model Definition
rnn_model = Sequential([
    SimpleRNN(50, return_sequences=True, input_shape=(SEQ_LENGTH, X_train.shape[2])),
    SimpleRNN(50),
    Dense(1)
])

rnn_model.compile(optimizer='adam', loss='mean_squared_error')

# Simple RNN Model Training
rnn_history = rnn_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

# Simple RNN Model Evaluation
rnn_predictions = rnn_model.predict(X_test)

# Calculate evaluation metrics for Simple RNN
rnn_r2 = r2_score(y_test, rnn_predictions)
rnn_mae = mean_absolute_error(y_test, rnn_predictions)
rnn_mse = mean_squared_error(y_test, rnn_predictions)
rnn_rmse = np.sqrt(rnn_mse)

print(f'Simple RNN - R² Score: {rnn_r2}')
print(f'Simple RNN - Mean Absolute Error (MAE): {rnn_mae}')
print(f'Simple RNN - Mean Squared Error (MSE): {rnn_mse}')
print(f'Simple RNN - Root Mean Squared Error (RMSE): {rnn_rmse}')

# %%
# Simple RNN
plt.figure(figsize=(10,6))
plt.plot(rnn_history.history['loss'], label='Training Loss')
plt.plot(rnn_history.history['val_loss'], label='Validation Loss')
plt.title('Simple RNN Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Actual Vs Predicted Consumption</p>

# %%
plt.figure(figsize=(16, 12))
# Simple RNN
plt.subplot(2, 1, 1)
plt.plot(y_test, label='Actual', color='blue')
plt.plot(rnn_predictions, label='Predicted', color='red', linestyle='dashed')
plt.title('Simple RNN Actual vs Predicted Consumption')
plt.xlabel('Time')
plt.ylabel('Consumption')
plt.legend()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">LSTM-Based Time Series Forecasting of Electricity Consumption</p>

# %%
# Feature Engineering: Add time-based features
df['hour'] = pd.to_datetime(df['DateTime']).dt.hour
df['dayofweek'] = pd.to_datetime(df['DateTime']).dt.dayofweek

# Normalize the data
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df[['Consumption', 'Production', 'Nuclear', 'Wind', 'Hydroelectric', 'Oil and Gas', 'Coal', 'Solar', 'Biomass', 'hour', 'dayofweek']])

# Convert to a DataFrame
scaled_df = pd.DataFrame(scaled_df, columns=['Consumption', 'Production', 'Nuclear', 'Wind', 'Hydroelectric', 'Oil and Gas', 'Coal', 'Solar', 'Biomass', 'hour', 'dayofweek'])

# Create sequences
def create_sequences(df, seq_length):
    sequences = []
    labels = []
    for i in range(len(df) - seq_length):
        seq = df.iloc[i:i+seq_length].values
        label = df['Consumption'].iloc[i+seq_length]
        sequences.append(seq)
        labels.append(label)
    return np.array(sequences), np.array(labels)

SEQ_LENGTH = 24  # for 24 hours sequence
sequences, labels = create_sequences(scaled_df, SEQ_LENGTH)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(sequences, labels, test_size=0.2, shuffle=False)

# Model Definition
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(SEQ_LENGTH, X_train.shape[2])),
    Dropout(0.2),
    LSTM(50),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)

# Model Training
history = model.fit(X_train, y_train, epochs=30, batch_size=32, validation_split=0.2, callbacks=[early_stopping, reduce_lr])

# Model Evaluation
predictions = model.predict(X_test)

# Calculate evaluation metrics
r2 = r2_score(y_test, predictions)
mae = mean_absolute_error(y_test, predictions)
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)

print(f'R² Score: {r2}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Actual Vs Predicted Consumption</p>

# %%
# Plot predictions vs actual values
plt.figure(figsize=(14, 5))
plt.plot(y_test, label='Actual Consumption')
plt.plot(predictions, label='Predicted Consumption')
plt.title('Actual vs Predicted Electricity Consumption')
plt.xlabel('Time')
plt.ylabel('Consumption')
plt.legend()
plt.show()

# %%
# Plot training & validation loss values
plt.figure(figsize=(14, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">Conclusion</p>

# %% [markdown]
# * This is Hourly timeseries Electricity Consumption and production Dataset.
# * It includes the hourly consumption and production, and the production is split in one of the categories: Nuclear, Wind, Hydroelectric, Oil and Gas, Coal, Solar, Biomass.
# * It's a big data set of more than 5 years!
# * When the production is greater than the consumption it means we are exporting electricity, when the value is smaller it means we are importing electricity.
# * All values of this dataset are in MWs
# * For this I Firstly Load and Display the Dataset and then i create the plots in order to explore the dataset and took the insights about ELectricity Consumption.
# * Then I apply the RNN na LSTM to forecast Electricity production and consumption
# * Both of this gives the amazing result but the LSTM performs slightly well then RNN.

# %% [markdown]
# # <p style="background-color: #a7de28; color: #c21919; font-family: 'Arial', sans-serif; font-size: 30px; text-align: center; padding: 25px 8px; border-radius: 10px; width: 90%; margin: 0 auto; font-weight: bold; text-shadow: 2px 2px 4px #fffafa; border: 5px solid #c21919;">⚡Thank you for taking the time to explore my Notebook.If you have any Question then Feel Free to ask⚡</p>
